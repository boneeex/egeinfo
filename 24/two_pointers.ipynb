# %% [markdown]
# Текстовый файл содержит строку из заглавных латинских букв и точек, всего не более 106 символов. Определите максимальное количество идущих подряд символов, среди которых не более шести точек и более 15 гласных букв (AEIOUY).

# %%
from collections import defaultdict
file = open(r"D:\informaticsclass\egeinfo\24\24_M3__42nfh.txt")
file = file.readline()

d = defaultdict(int)
p = mx = start = 0
for end in range(len(file)):
    if file[end] in "AEIOUY":
        d[file[end]] += 1
    if file[end] == ".":
        p += 1

    while p > 6:
        if file[start] in "AEIOUY":
            d[file[end]] -= 1
        if file[start] == ".":
            p -= 1
        start += 1
    if p <= 6 and sum(d.values()) > 15:
        mx = max(mx, end - start + 1)
print(mx)
# Out:
# 592

# %% [markdown]
# Текстовый файл состоит из символов T,U,V,W,X,Y и Z.
# Определите в прилагаемом файле максимальное количество идущих подряд символов (длину непрерывной подпоследовательности), среди которых символ T   встречается ровно 100 раз.
# Для выполнения этого задания следует написать программу

# %%
file = open(r"D:\informaticsclass\egeinfo\24\24_2024__7aiiq.txt")
file = file.readline()

mx = t = start = 0
for end in range(len(file)):
    if file[end] == "T":
        t += 1
    while t > 100:
        if file[start] == "T":
            t -= 1
        start += 1
    if t == 100:
        mx = max(mx, end - start + 1)

print(mx)

# %% [markdown]
# Текстовый файл содержит только заглавные буквы латинского алфавита. Определите максимальное количество идущих подряд символов,
# среди которых каждая из букв F, L встречается не более трех раз.

# %%
file = open(r"D:\informaticsclass\egeinfo\24\24_18__3b9tx.txt").readline()

mx = f = l = start = 0
for end in range(len(file)):
    if file[end] == "F":
        f += 1
    if file[end] == "L":
        l += 1
    
    while f > 3 or l > 3:
        if file[start] == "F":
            f -= 1
        if file[start] == "L":
            l -= 1
        start += 1
    if f <= 3 and l <= 3:
        mx = max(mx, end - start + 1)
print(mx)

# %% [markdown]
# Текстовый файл состоит не более чем из 106 символов латинского алфавита. Определите длину минимальной подстроки, содержащей не менее 100 символов Y.
#
# Для выполнения этого задания следует написать программу.

# %%
f = open(r"D:\informaticsclass\egeinfo\24\24_16__3b9u2.txt").readline()

start = y = 0
mn = 10 ** 7

for end in range(len(f)):
    if f[end] == "Y":
        y += 1

    while y > 100:
        if f[start] == "Y":
            y -= 1
        start += 1
    
    if y == 100:
        mn = min(mn, end - start + 1)

print(mn)

# %% [markdown]
# Текстовый файл 24_4.txt состоит из символов A, C, D, F и O.
#
# Определите в прилагаемом файле максимальное количество идущих подряд символов (длину непрерывной подпоследовательности), среди которых символ D встречается не более 100 раз.
#
# Для выполнения этого задания следует написать программу.

# %%
f = open(r"D:\informaticsclass\egeinfo\24\24_4__3b9tg.txt").readline()

mx = start = d = 0

for end in range(len(f)):
    if f[end] == "D":
        d += 1
    
    while d > 100:
        if f[start] == "D":
            d -= 1
        
        start += 1
    
    if d <= 100:
        mx = max(mx, end - start + 1)
print(mx)

# %% [markdown]
# Текстовый файл содержит только заглавные буквы латинского алфавита (ABC...Z).
# Определите максимальное количество идущих подряд символов, среди которых ровно по одному разу встречаются буквы X и Y.

# %%
file = open(r"D:\informaticsclass\egeinfo\24\24__7h7ej.txt").readline()

mx = start = y = x = 0

for end in range(len(file)):
    if file[end] == "Y":
        y += 1
    if file[end] == "X":
        x += 1

    while x > 1 or y > 1:
        if file[start] == "X":
            x -= 1
        if file[start] == "Y":
            y -= 1

        start += 1

    if x == 1 and y == 1:
        mx = max(mx, end - start + 1)

print(mx)

# %% [markdown]
# Текстовый файл содержит только заглавные буквы латинского алфавита (ABC...Z).
# Определите максимальное количество идущих подряд символов, среди которых каждая из букв C и D встречается не более двух раз.

# %%
file = open(r"D:\informaticsclass\egeinfo\24\24__7h77f.txt").readline()

mx = start = c = d = 0

for end in range(len(file)):
    if file[end] == "C":
        c += 1
    if file[end] == "D":
        d += 1
    
    while c > 2 or d > 2:
        if file[start] == "D":
            d -= 1
        if file[start] == "C":
            c -= 1
        start += 1
    
    if c <= 2 and d <= 2:
        mx = max(mx, end - start + 1)
print(mx)

# %% [markdown]
# Текстовый файл содержит только заглавные буквы латинского алфавита (ABC...Z).
# Определите максимальное количество идущих подряд символов, среди которых каждая из букв UVWXYZ встречается не более ста раз.

# %%
from collections import defaultdict
file = open(r"D:\informaticsclass\egeinfo\24\24__7h6ti.txt").readline()

mx = start = 0
d = defaultdict(int)
d[0] = 0

for end in range(len(file)):
    if file[end] in "UVWXYZ":
        d[file[end]] += 1
    
    while max(d.values()) > 100:
        if file[start] in "UVWXYZ":
            d[file[start]] -= 1
        start += 1

    if max(d.values()) <= 100:
        mx = max(mx, end - start + 1)

print(mx)

# %% [markdown]
# Текстовый файл содержит строку из заглавных латинских букв и точек, всего не более 106 символов.
# Определите максимальное количество идущих подряд символов, среди которых не более шести точек и более 15 гласных букв (AEIOUY).

# %%
file = open(r"D:\informaticsclass\egeinfo\24\24_M3__42nfh (1).txt").readline()

mx = start = gl = point = 0

for end in range(len(file)):
    if file[end] in "AEIOUY":
        gl += 1
    if file[end] == ".":
        point += 1

    while point > 6:
        if file[start] == ".":
            point -= 1
        if file[start] in "AEIOUY":
            gl -= 1
        start += 1

    if point <= 6 and gl > 15:
        mx = max(mx, end - start + 1)
print(mx)

# %% [markdown]
# № 4306 /dev/inf 06.2022 (Уровень: Средний)
#
# Текстовый файл состоит не более, чем из 106 символов латинского алфавита A, B, C, D ... Z.
#
# Определите максимальное количество подряд идущих символов, среди которых нет символа R, а количество символов А не превышает 3.

# %%
file = open(r"D:\Study\egeinfo\24\24_4306.txt").readline()

r = a = mx = start = 0
for end in range(len(file)):
    if file[end] == "A":
        a += 1
    if file[end] == "R":
        r += 1
    
    while r > 0 or a > 3:
        if file[start] == "A":
            a -= 1
        if file[start] == "R":
            r -= 1
        start += 1
    if r == 0 and a <= 3:
        mx = max(mx, end - start + 1)

print(mx)

# %% [markdown]
# № 5381 /dev/inf 12.2022 (Уровень: Сложный)
#
# (А. Рогов) Текстовый файл состоит из символов A, B, C, D, E, F и U. Определите максимальное количество идущих подряд символов в прилагаемом файле, среди которых комбинация
#
# согласная + гласная + согласная
#
# встречается ровно 2 раза.

# %%
import re
file = open(r"D:\Study\egeinfo\24\24_5381.txt").readline()

pattern = "([BCDF][AEU][BCDF])"
lst = []
for i in re.finditer(pattern, file):
    lst.append(i.group())

file = file.split(*lst)

print(file)

# %% [markdown]
# № 3099 (Уровень: Гроб)
#
# (PRO100 ЕГЭ) Текстовый файл содержит строку из заглавных латинских букв, всего не более чем из 106 символов. Требуется заменить некоторые буквы на другие латинские так, чтобы из букв получившейся строки можно было собрать палиндром. В ответ запишите минимальное количество замен, которое нужно сделать.
#
# Пример:
#
# Из строки wqe, строка wqq (можно собрать палиндром qwq) получается с помощью одной замены e -> q.

# %%
from collections import Counter
file = open(r"D:\Study\egeinfo\24\24_3099.txt").readline()

k_s = Counter(file).values()
lst = [i for i in k_s if i % 2]
if len(lst) % 2 == 0:
    print(len(lst) // 2)
else:
    print((len(lst) - 1) // 2)
# Out:
# 7

# %% [markdown]
# № 14704 (Уровень: Сложный)
#
# (П. Говоров) Программист Павел "Setzor" любит составлять различные строки из букв. В файле содержится строка длиной не более 107 из заглавных букв латинского алфавита (ABC…Z).
# Определите в прилагаемом файле максимальную длину подпоследовательности, которая состоит из двух последовательных частей (сначала 1 часть, затем 2):
# в первой части символы расположены в алфавитном порядке, во второй в обратном алфавитном порядке. (1-ая и 2-ая часть могут быть различной длины).
#
# Например, для строки QTUHHMSMJFSMECQ ответом будет являться подпоследовательность HHMSMJF (ответ 7), в которой 1 часть - HHMS, 2 - часть MJF (разделить можно также на части HHM и SMJF).

# %%
file = open(r"D:\Study\egeinfo\24\24_14704.txt").readline()
mx = -1
state = "01"
cnt = 1
lst = []
for i in range(len(file) - 1):
    a = file[i]
    b = file[i + 1]

    # end of 2 stage
    if a < b and state == "10":
        mx = max(mx, cnt)
        lst.append(file[i + 1 - cnt:i + 2])
        cnt = 2
    else:
        cnt += 1

    if a < b:
        state = "01"
    else:
        state = "10"


print(max(mx, cnt))
print(len("BMPUXYOHGGGEDCAAC"))
# Out:
# 17

# %%
# IUGHSO
# dp1 == [1]
# dp1 = [1, 2, 1, 2, 3, 1]
# dp2 = [1, 2, 1, 1, 2, 1]

# %% [markdown]
# № 9753 Основная волна 19.06.23 (Уровень: Сложный)
#
# Текстовый файл состоит из символов T, U, V, W, X, Y и Z.
# Определите в прилагаемом файле максимальное количество идущих подряд символов (длину непрерывной подпоследовательности), среди которых символ Y встречается не более 150 раз.

# %%
file = open(r"D:\Study\egeinfo\24\24_9753.txt").readline()
mx = start = y = 0

for end in range(len(file)):
    if file[end] == "Y":
        y += 1
    
    while y > 150:
        if file[start] == "Y":
            y -= 1
        start += 1

    if y <= 150:
        mx = max(mx, end - start + 1)

print(mx)
# Out:
# 244

# %% [markdown]
# № 18530 (Уровень: Сложный)
#
# (Л. Шастин) Текстовый файл состоит из символов A, B, C, D, E, F, G и H.
#
# Определите максимальное количество идущих подряд символов в прилагаемом файле, среди которых последовательность расстояний между ближайшими соседними гласными буквами образует арифметическую прогрессию.
#
# Например, в строке BBDABCADEFBACDFAB подходит подстрока BCADEFBACDFAB, последовательность расстояний между ближайшими соседними гласными буквами в ней образована с шагом 1 и выглядит так: 2, 3, 4.
#
# Примечание. Под расстоянием понимается разница индексов.

# %%
file = open(r"D:\Study\egeinfo\24\24_18530.txt").readline().strip()

n = len(file)
v = [i for i, ch in enumerate(file) if ch in "AE"]
m = len(v)
mx = 0

mx = max(mx, v[0])
mx = max(mx, n - 1 - v[-1])
for i in range(m - 1):
    mx = max(mx, v[i + 1] - v[i] - 1)

for i in range(m):
    l = v[i - 1] + 1 if i > 0 else 0
    r = v[i + 1] - 1 if i + 1 < m else n - 1
    mx = max(mx, r - l + 1)

for i in range(m - 1):
    l = v[i - 1] + 1 if i > 0 else 0
    r = v[i + 2] - 1 if i + 2 < m else n - 1
    mx = max(mx, r - l + 1)

d2 = [v[i + 2] - 2 * v[i + 1] + v[i] for i in range(m - 2)]
st = 0
for i in range(1, len(d2) + 1):
    if i == len(d2) or d2[i] != d2[st]:
        i0 = st
        j0 = i + 1
        l = v[i0 - 1] + 1 if i0 > 0 else 0
        r = v[j0 + 1] - 1 if j0 + 1 < m else n - 1
        mx = max(mx, r - l + 1)
        st = i

print(mx)
# Out:
# 107831

# %% [markdown]
# № 3091 (Уровень: Гроб)
#
# Текстовый файл состоит не более чем из 106 заглавных латинских букв (A..Z). Текст разбит на строки различной длины. Определите количество строк, в которых есть хотя бы одна подстрока, состоящая из 7 символов, которая либо изначально является палиндромом, либо может быть преобразована к палиндромическому виду путём максимум одной перестановки (двух символов), которая выполняется в рамках текущей подстроки.
#
# Например, даны строки:
# AFDGADGHAGHGJAGJ - здесь нет палиндромов длины 7, перестановка тоже не помогает.
# ADGHADGOJAJAG - здесь ADGHADG преобразовывается в GDAHADG (G и A поменялись местами).
# ABDGJHAGDJGAJHA - здесь нет палиндромов длины 7, перестановка тоже не помогает.
# Подошла одна строка. Ответ: 1.
#
# Примечание: палиндром - последовательность символов, которая читается
# одинаково как вперёд, так и назад, например "BABAB".

# %%
file = open(r"D:\Study\egeinfo\24\24__3091 (1).txt")

def check_palindrom(spl: list) -> bool:
    lst = list(set([i for i in spl if spl.count(i) % 2]))
    if len(lst) != 1: return False
    ancestor = spl.copy()
    # если символ, встречающийся нечетное кол-во раз, стоит посередине
    if spl[3] == lst[0]:
        for left_idx in range(3):
            for right_idx in range(4, 7):
                spl[left_idx], spl[right_idx] = spl[right_idx], spl[left_idx]
                if spl[:3] == spl[4:][::-1]: 
                    return True
                else:
                    spl = ancestor.copy()
    # если символ, встречающийся нечетное кол-во раз, не стоит посередине
    # то пытаемся его с кем то поменять
    for i in range(len(spl)):
        spl[i], spl[3] = spl[3], spl[i]
        if spl[:3] == spl[4:][::-1]: 
            return True
        else:
            spl = ancestor.copy()
    return False

cnt = 0
for line in file:
    for i in range(7, len(line)):
        if check_palindrom(list(line[i - 7:i])):
            cnt += 1
            break

print(cnt)
# Out:
# 996

# %% [markdown]
# № 9552 Джобс 14.06.23 (Уровень: Сложный)
#
# В файле содержится строка длиной не более 10^6 из букв английского алфавита. Определите максимальную длину подпоследовательности, которая состоит только из пар символов PC, только из четверок символов CSGO, или из непересекающихся пар символов PC и четверок символов CSGO.
#
# Например, в строке ASDPCCSGOPCNGCHPCPCSGOPC есть три подходящие подпоследовательности PCCSGOPC, PCPC и CSGOPC. Максимальная длина – 8.

# %%
file = open(r"D:\informaticsclass\egeinfo\24\24_9552.txt").readline()

lst = [0 for i in range(len(file))]
for i in range(len(file)):
    try:
        pc = file[i - 1:i + 1]
        csgo = file[i - 3:i + 1]
        if pc == "PC":
            lst[i] = 2 + lst[i - 2]
        if csgo == "CSGO":
            lst[i] = 4 + lst[i - 4]
    except:
        continue

print(max(lst))

# %%
file = open(r"D:\informaticsclass\egeinfo\24\24_9552.txt").readline()
from re import *

pattern = "((CSGO)|(PC))+"
pattern = f"(?=({pattern}))"

mx = 0
iss = []
for i in finditer(pattern, file):
    mx = max(mx, len(i.group(1)))
    iss.append(i.group(1))
print(mx)
print(max(iss, key=len))

# %% [markdown]
# № 11636 (Уровень: Сложный)
#
# (Л. Шастин) Текстовый файл состоит не более, чем из 7 200 000 прописных символов латинского алфавита.
#  Определите в прилагаемом файле количество подстрок вида A#A, где на месте # стоит хотя бы один символ.

# %%
file = open(r"D:\informaticsclass\egeinfo\24\24_11636.txt").readline()

aa = len([1 for i in range(1, len(file)) if file[i - 1] + file[i] == "AA"])
a_n = file.count("A")

print((a_n * (a_n - 1)) // 2 - aa)
# Out:
# 42587173055

# %% [markdown]
# № 18619 (Уровень: Сложный)
#
# Текстовый файл состоит из цифр от 1 до 6, знаков операций «–» и «*» (вычитание и умножение) и заглавных латинских букв A, B, C, D.
# Определите максимальное количество символов в непрерывной последовательности символов, состоящей из буквы B, за которой следует корректное арифметическое выражение с целыми неотрицательными числами, записанными в десятичной системе счисления.

# %%
file = open(r"D:\informaticsclass\egeinfo\24\24_18619.txt").readline()
from re import *

num = "([1-6]+)"
pattern = f"[B]{num}([-*]{num})*"

mx = 0
for i in finditer(pattern, file):
    mx = max(mx, len(i.group()))
print(mx)
# Out:
# 68

# %% [markdown]
# № 12410 (Уровень: Средний)
#
# (Л. Шастин) Текстовый файл состоит не более, чем из 7 200 000 прописных символов латинского алфавита.
#
# Определите в прилагаемом файле максимальное количество идущих подряд символов, среди которых прямой алфавитный порядок нарушается ровно 100000 раз.
#
# Например, в подстроке AABCEGBCDFXCDEFA прямой алфавитный порядок нарушается ровно трижды.

# %%
file = open(r"D:\informaticsclass\egeinfo\24\dz_24_3.txt").readline()
dp = [0 for i in range(len(file))]

for i in range(1, len(file)):
    if file[i] < file[i - 1]:
        dp[i] = 1

mx = one = start = 0
for end in range(len(dp)):
    if dp[end] == 1:
        one += 1
    
    while one > 100000:
        if dp[start] == 1:
            one -= 1
        
        start += 1
    
    if one == 100000:
        mx = max(mx, end - start + 2)

print(mx)
# 1010101001010100111001
# Out:
# 218686

# %% [markdown]
# № 16269 Джобс 03.05.24 (Уровень: Средний)
#
# (Е.Джобс) Текстовый файл состоит из символов T, U, V, W, X, Y и Z.
#
# Определите в прилагаемом файле максимальную длину подстроки, состоящую из пар символов XX, YY или ZZ в произвольном порядке, при этом ни одна пара не должна повторяться два раза подряд. Например, в строке YYZZZZYYXX искомая подстрока ZZYYXX.

# %%
file = open(r"D:\informaticsclass\egeinfo\24\24_16269.txt").readline()
dp = [0 for i in range(len(file))]
if file[:2] in ["XX", "YY", "ZZ"]: 
    dp[1] = 2

for i in range(3, len(file)):
    srez = file[i - 1: i + 1]
    if srez in ["XX", "YY", "ZZ"] and file[i - 3: i - 1] != srez:
        dp[i] = 2 + dp[i - 2]
    elif srez in ["XX", "YY", "ZZ"]:
        dp[i] = 2

print(max(dp))
# Out:
# 52

# %% [markdown]
# № 22446 (Уровень: Сложный)
#
# (Л. Шастин) Текстовый файл состоит из символов L, N и D. Определите в этом файле максимальное количество идущих подряд символов, среди которых подстрока LND встречается не более 10000 раз, при этом искомая последовательность начинается и заканчивается на одну и ту же букву.

# %%
file = open(r"D:\Study\egeinfo\24\24_22446.txt").readline()
file = file.replace("LND", "*")
file = file.split("*")
mx = 0
for i in range(len(file) - 10_000):
    first = file[i] + "LND"
    last = "LND" + file[i + 10_000]
    mx = max(mx,
             len(first) - first.find("L") + 9999 * 3 + last.rfind("L") + sum(len(file[y]) for y in range(i + 1, i + 10_000)))
    mx = max(mx,
             len(first) - first.find("N") + 9999 * 3 + last.rfind("N") + sum(len(file[y]) for y in range(i + 1, i + 10_000)))
    mx = max(mx,
             len(first) - first.find("D") + 9999 * 3 + last.rfind("D") + sum(len(file[y]) for y in range(i + 1, i + 10_000)))
print(mx)
# правильный ответ 830019
# Out:
# 830019

# %%
file = open(r"D:\Study\egeinfo\24\24_22446.txt").readline()
file = file.replace("LND", "*")
file = file.split("*")

# Префиксные суммы длин сегментов
prefix = [0] * (len(file) + 1)
for j in range(len(file)):
    prefix[j + 1] = prefix[j] + len(file[j])

mx = 0

# Случай 1: вхождений LND < 10000 — весь файл подходит
if len(file) <= 10_002:
    whole = "LND".join(file)
    for c in "LND":
        fi = whole.find(c)
        la = whole.rfind(c)
        if fi != -1:
            mx = max(mx, la - fi + 1)

# Случай 2: окно ровно из 10000 вхождений LND
for i in range(len(file) - 10_002):
    first = file[i] + "LND"
    last  = "LND" + file[i + 10_002]
    middle_sum = prefix[i + 10_002] - prefix[i + 1]
    base = 10_000 * 3 + middle_sum

    for c in "LND":
        fi = first.find(c)
        la = last.rfind(c)
        if fi != -1 and la != -1:
            mx = max(mx, (len(first) - fi) + base + (la + 1))

print(mx)
# Out:
# 830181

# %% [markdown]
# Джобс Е.Тема: Обработка строк(Обработка строк)
# Текстовый файл состоит не более, чем из
# 10
# 7
# 10
# 7
#   символов из набора A, B, C, D, E, F.
#
# Найдите максимальную длину строки вида А*А*А*А, где между буквами А расположены одинаковые группы символов, не содержащие букв А. Например, в строке BDADBADBADBABDAFABDA такая подстрока ADBADBADBA (длина 10).
#
# Для выполнения этого задания следует написать программу.

# %%
file = open(r"D:\informaticsclass\egeinfo\24\24 (2).txt").readline()
file = file.split("A")

mx = 0
for i in range(len(file) - 3):
    window = file[i:i + 3]
    if window[0] == window[1] and window[0] == window[2]:
        mx = max(mx, sum(list(map(len, window))) + 4)
print(mx)

# %% [markdown]
# № 18530 (Уровень: Сложный)
# (Л. Шастин) Текстовый файл состоит из символов A, B, C, D, E, F, G и H.
# Определите максимальное количество идущих подряд символов в прилагаемом файле, среди которых последовательность расстояний между ближайшими соседними гласными буквами образует арифметическую прогрессию.
# Например, в строке BBDABCADEFBACDFAB подходит подстрока BCADEFBACDFAB, последовательность расстояний между ближайшими соседними гласными буквами в ней образована с шагом 1 и выглядит так: 2, 3, 4.
# Примечание. Под расстоянием понимается разница индексов.

# %% [markdown]
# № 22446 (Уровень: Сложный)
#
# (Л. Шастин) Текстовый файл состоит из символов L, N и D. Определите в этом файле максимальное количество идущих подряд символов, среди которых подстрока LND встречается не более 10000 раз, при этом искомая последовательность начинается и заканчивается на одну и ту же букву.

# %%
file = open(r"D:\informaticsclass\egeinfo\24\24_22446 (1).txt").readline()
file = file.replace("LND", "*")
file = file.split("*")
sm = [0 for i in range(len(file))]
sm[0] = len(file[0])
for i in range(1, len(file)):
    sm[i] = sm[i - 1] + len(file[i])

mx = 0
for i in range(10_001, len(file)):
    try:
        win_sm = sm[i] - sm[i - 10_001]
    except:
        win_sm = sm[i]
    mx = max(mx, win_sm + 4 + 10_000 * 3)
print(mx)
# Out:
# 830022

# %%
with open(r"D:\informaticsclass\egeinfo\24\24_22446 (1).txt") as f:
    s = f.readline().strip()

chunks = s.split("LND")
n = len(chunks)

sm = [0] * n
sm[0] = len(chunks[0])
for i in range(1, n):
    sm[i] = sm[i-1] + len(chunks[i])

K = 10000
best = 0

for i in range(K, n):
    a, b = i - K, i                       # 10001 кусок, между ними 10000 LND
    middle = sm[b] - (sm[a-1] if a > 0 else 0)
    base = middle + K * 3                 # длина без расширений

    # (символ, доп. длина) для левой границы
    starts = []
    if chunks[a]:
        starts.append((chunks[a][0], 0))
    else:                                 # пустой кусок — окно начинается с L следующего LND
        starts.append(('L', 0))
    if a > 0:                             # есть LND слева — можно расшириться
        starts.append(('D', 1))
        starts.append(('N', 2))

    # (символ, доп. длина) для правой границы
    ends = []
    if chunks[b]:
        ends.append((chunks[b][-1], 0))
    else:                                 # пустой кусок — окно кончается на D предыдущего LND
        ends.append(('D', 0))
    if b < n - 1:                         # есть LND справа
        ends.append(('L', 1))
        ends.append(('N', 2))

    for sc, sx in starts:
        for ec, ex in ends:
            if sc == ec:
                best = max(best, base + sx + ex)

print(best)
# Out:
# 830019

# %% [markdown]
# https://education.yandex.ru/ege/inf/task/79093caa-18f3-4e6f-80d5-7e4135f2741a
# Текстовый файл состоит из десятичных цифр и заглавных букв латинского алфавита. Определите в прилагаемом файле последовательность из максимального количества идущих подряд символов, которая начинается с буквы A, заканчивается буквой Z (единственной в последовательности), содержит ровно 50 гласных букв латинского алфавита (A, E, I, O, U) и при этом сумма всех цифр в этой последовательности кратна 7.

# %%
file = open(r"D:\informaticsclass\egeinfo\24\24 (3).txt").readline()
print(len(file))
file = file.split("Z")
alp = "AEIOU"

def f(s):
    cnt = 0
    for i in s:
        try:
            cnt += int(i)
        except:
            continue
    return cnt

mx = 0
for line in file:
    for i in range(len(line)):
        a = line[i:]
        if line[i] == "A" and f(line[i:]) % 7 == 0 and a.count("A") + a.count("E") + a.count("I") + a.count("U") + a.count("O") == 50:
            mx = max(mx, len(line) - i + 1)
print(mx)
# Out:
# 3480301
# 707

# %% [markdown]
# https://education.yandex.ru/ege/inf/task/f1c21f0a-f47e-4d73-ac45-c4b8eecec1df
# Текстовый файл состоит из десятичных цифр и заглавных букв латинского алфавита. Определите в прилагаемом файле последовательность символов, состоящую из максимального количества идущих подряд цифр, начинающуюся и заканчивающуюся одинаковыми буквами, содержащую ровно две буквы: первую и последнюю. Если таких несколько, выберите последовательность с наименьшим порядковым номером в файле её первого символа. В ответе запишите число — порядковый номер в файле первого символа найденной последовательности.
#
# Для выполнения этого задания следует написать программу.
#
# Примечание. В прилагаемом файле нумерация символов начинается с нуля.

# %%
file = open(r"D:\informaticsclass\egeinfo\24\24 (4).txt").readline()
from re import *
from string import printable
alp = printable[36:62]

for letter in alp:
    file.replace(letter, letter + letter)

res = []
for letter in alp:
    pattern = f"[{letter}]([0-9]+)[{letter}]"
    for i in finditer(pattern, file):
        res.append(i.group())

new_res = sorted([(len(i), file.find(i)) for i in res], key=lambda x: [-x[0], x[1]])
print(new_res[0])
# Out:
# (1952, 310030)

# %% [markdown]
# https://education.yandex.ru/ege/inf/task/3594e81a-4775-400e-97ce-64c0fcd1e711
# Текстовый файл состоит из десятичных цифр и заглавных букв латинского алфавита. Определите в прилагаемом файле максимальное количество идущих подряд символов, среди которых подстрока 2025 встречается не менее 90 раз и при этом содержится ровно 80 букв Y.
#
# В ответе запишите число — количество символов в найденной последовательности.
# Для выполнения этого задания следует написать программу.

# %%
file = open(r"D:\informaticsclass\egeinfo\24\24 (5).txt").readline()
file = file.replace("2025", "*")

twok = y = start = mx = 0
for end in range(len(file)):
    if file[end] == "*":
        twok += 1
    if file[end] == "Y":
        y += 1

    while y > 80:
        if file[start] == "Y":
            y -= 1
        if file[start] == "*":
            twok -= 1

        start += 1
    
    if twok >= 90 and y == 80:
        mx = max(mx, end - start + 1 + 3 * twok)
print(mx)
# Out:
# 2981

# %% [markdown]
# https://education.yandex.ru/ege/inf/task/14f0894b-7da9-48ac-b096-d94b9066c0d8
# Текстовый файл содержит цифры от 0 до 9.
#
# Найдите длину самой длинной подстроки, состоящей из последовательности возрастающих на единицу чисел, которая содержит число 78 как один из элементов.
#
# Верной подстрокой считается непрерывная цепочка цифр, которую образуют числа, идущие по порядку (например, 45464748 или 4567).
#
# Например, для строки 12345678910111278156178798081828384 ответ будет 14, так как самая длинная подстрока, подходящая под условие, 78798081828384, содержит 14 цифр. Подстрока 123456789101112 не подходит, так как число 78 должно являться частью идущих по порядку чисел.

# %%
file = open(r"D:\informaticsclass\egeinfo\24\24 (6).txt").readline()

left_prefix = ["78"] * 79
for i in range(77, -1, -1):
    left_prefix[77 - i] = str(i) + left_prefix[77 - i - 1] 
left_prefix = ["78"] + left_prefix[:len(left_prefix) - 1]
mx = 0
k = 500
right_suffix = ["78"] * (k + 1)
for i in range(79, 79 + k):
    right_suffix[i - 79] = right_suffix[i - 79 - 1] + str(i)
right_suffix = right_suffix[:len(right_suffix) - 1]
right_suffix = list(map(lambda x: x[2:], right_suffix))

res = []
for left in left_prefix:
    for right in right_suffix:
        spl = left + right
        flag = file.find(spl)
        if flag >= 0:
            mx = max(mx, len(spl))
            res.append(spl)
        else:
            break
print(mx)
# Out:
# 77

# %% [markdown]
# https://education.yandex.ru/ege/inf/task/37e7362a-fc21-4cc7-acb1-3859dde6d2ef
# Текстовый файл состоит из символов латинского алфавита K, L, M, N, и цифр 1, 2, 3.
# Определите в прилагаемом файле максимальное количество идущих подряд символов, среди которых букв ровно в два раза больше, чем цифр.

# %%
file = open(r"D:\informaticsclass\egeinfo\24\24 (7).txt").readline()
for i in "KLMN":
    file = file.replace(i, "!")
for i in "123":
    file = file.replace(i, "?")

balance = 0
last_seen = {0: -1}
mx = 0

for i, ch in enumerate(file):
    if ch == "!":
        balance += 1
    elif ch == "?":
        balance -= 2

    if balance in last_seen:
        mx = max(mx, i - last_seen[balance])
    else:
        last_seen[balance] = i

print(mx)
# Out:
# 333

# %% [markdown]
# 29354

# %%
file = open(r"D:\informaticsclass\egeinfo\24\24_29354.txt").readline()
file = file.replace("BC", "*")

start = point = mx = 0
for end in range(len(file)):
    if file[end] == "*":
        point += 1
    
    while point > 190:
        if file[start] == "*":
            point -= 1
        
        start += 1
    
    if point == 190: mx = max(mx, end - start + 1 + 190 + 2)
print(mx)
# Out:
# 2287

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
file = open(r"D:\informaticsclass\egeinfo\24\24_26549.txt").readline()
file = file.split("2025")[:len(file.split("2025")) - 1]

prefix = [len(file[0])] + [0] * (len(file) - 1)
prefixy = [file[0].count("Y")] + [0] * (len(file) - 1)
for i in range(1, len(file)):
    prefix[i] = prefix[i - 1] + len(file[i])
    prefixy[i] = prefixy[i - 1] + file[i].count("Y")

mx = 0
for i in range(50, len(file)):
    curr_y = prefixy[i] - prefixy[i - 50]
    curr_len = prefix[i] - prefix[i - 50]
    if curr_y >= 140:
        mx = max(mx, curr_len + 4 * 50 + 3)
print(mx)
# 938
# Out:
# BYXNVDYUL9
# 938

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from string import printable
from re import *
file = open(r"D:\informaticsclass\egeinfo\24\24 (8).txt").readline()
alp = printable[36:62]

res = []
for letter in alp:
    pattern = f"[{letter}]([0-9]+)[{letter}]"
    for i in finditer(pattern, file):
        res.append((len(i.group()), file.index(i.group())))
print(sorted(res, key=lambda x: [-x[0], x[1]])[0][1])
# Out:
# 310030
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
file = open(r"D:\informaticsclass\egeinfo\24\24 (8).txt").read()
mx = 0
first = ""
for i in range(len(file)):
    if file[i].isalpha():
        if first == "":
            first = file[i]
            ind = i
        elif first == file[i]:
            if i - ind + 1 > mx:
                mx = i - ind + 1
                ans = ind
            ind = i
        else:
            first = file[i]
            ind = i
print(ans)
# Out:
# 310030

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from re import *
file = open(r'D:\informaticsclass\egeinfo\24\24 (9).txt').readline()
pattern = "([1-9A-E])([0-9A-E])*([124578ABDE])"

res = []
for i in finditer(pattern, file):
    i = i.group(1)
    res.append((len(i), file.index(i)))
print(sorted(res, reverse=True))
# Out:
# [(1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174), (1, 174
# ...

# %% [markdown]
# № 23206 Основная волна 10.06.25 (Уровень: Средний)
#
# Текстовый файл состоит из десятичных цифр и заглавных букв латинского алфавита. Определите в прилагаемом файле последовательность из максимального количества идущих подряд символов, среди которых ровно 35 букв S, начинающуюся чётной цифрой, не содержащую других чётных цифр, кроме первой.
# В ответе запишите число - количество символов в найденной последовательности.

# %%
file = open(r"D:\informaticsclass\egeinfo\24\24_23206.txt").readline()
for i in "02468": file = file.replace(i, "*")
file = file.split("*")[1:]

mx = 0
for line in file:
    if line.count("S") < 35: continue
    s = 0
    for i in range(len(line)):
        if line[i] == "S":
            s += 1
        if s == 35:
            mx = max(mx, i + 2)
        elif s > 35:
            break
print(mx)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
file = open(r"D:\informaticsclass\egeinfo\24\24 (10).txt").readline()
file = file.replace("BC", "B C").split()
prefix_sum = [len(file[0])]
for i in range(1, len(file)): prefix_sum.append(len(file[i]) + prefix_sum[i - 1])

mx = 0
for i in range(179, len(file)):
    if i == 180: mx = prefix_sum[i]
    else: mx = max(mx, prefix_sum[i] - prefix_sum[i - 181])
print(mx)
# Out:
# 38442

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
file = open(r"D:\informaticsclass\egeinfo\24\24_19489.txt").readline()
file = file.replace("WSFWW", "WSFW SFWW").split(" ")
mx = 0
for line in file:
    new_line = [0] * len(line)
    for i in range(2, len(line)):
        sub_stl = line[i - 2] + line[i - 1] + line[i - 0]
        if sub_stl == "WWF": 
            new_line[i - 2] = 1
            new_line[i - 1] = 1
            new_line[i - 0] = 1
    start = ones = 0
    # ones = 120 * 3 + 4 - ideal
    for end in range(len(new_line)):
        if new_line[end] == 1:
            ones += 1

        while ones > 364:
            if new_line[start] == 1:
                ones -= 1
            start += 1
        mx = max(mx, end - start + 1)
print(mx)
# Out:
# 3080

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
file = open(r"D:\informaticsclass\egeinfo\24\24 (11).txt").readline()

for i in "AEIOU": file = file.replace(i, "*")
file = file.split("Z")

def fin_idx(s, sub, income):
    poz = -1
    for _ in range(income):
        poz = s.find(sub, poz + 1)
    return poz

mx = 0
for line in file[:len(file) - 1]:
    line = line[::-1]
    left, right = fin_idx(line, "*", 50), fin_idx(line, "*", 51)
    if left == -1 or right == -1: continue
    for j in range(left, right):
        sum_n = sum([int(i) for i in line[:j + 1] if i in "0123456789"])
        if sum_n % 7 == 0: 
            mx = max(mx, j + 2) 
print(mx)
# Out:
# 708

# %%
s = open(r"D:\informaticsclass\egeinfo\24\24 (11).txt").readline().strip()
mx = 0
for seg in s.split("Z")[:-1]:          # каждый сегмент заканчивается буквой Z
    r = seg[::-1]                      # r[0] — символ прямо перед Z
    cnt, p = 0, -1
    for idx, ch in enumerate(r):
        if ch in "AEIOU":
            cnt += 1
            if cnt == 50:
                p = idx 
                break
    if p == -1:                        # гласных меньше 50 — последовательности нет
        continue
    if r[p] != "A":                    # 50-я гласная с конца обязана быть A
        continue
    s_sum = sum(int(ch) for ch in r[:p + 1] if ch.isdigit())
    if s_sum % 7 == 0:
        mx = max(mx, p + 2)            # p+1 символов тела + сама Z
print(mx)
# Out:
# 707
