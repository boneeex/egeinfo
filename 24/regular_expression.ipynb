# %% [markdown]
# Текстовый файл состоит из цифр от 1 до 6, знаков операций «–» и «*» (вычитание и умножение) и заглавных латинских букв A, B, C, D.
#
# Определите максимальное количество символов в непрерывной последовательности символов, состоящей из буквы B, за которой следует корректное арифметическое выражение с целыми неотрицательными числами, записанными в десятичной системе счисления.

# %%
from re import finditer
file = open(r"D:\informaticsclass\egeinfo\24\24__7h55c (1).txt").readline()
number = "[1-6][1-6]*"
reg = f"B{number}([-*]{number})*"
mx = 0
for i in finditer(reg, file):
    mx = max(mx, len(i.group()))
print(mx)

# %% [markdown]
# Текстовый файл состоит из цифр 6, 7, 8, 9, 0 и знаков арифметических операций «–» и «+» (вычитание и сложение).
# Определите максимальное количество символов в непрерывной последовательности, которая является корректным арифметическим выражением с целыми неотрицательными числами. В этом выражении никакие два знака арифметических операций не стоят рядом, в записи чисел отсутствуют незначащие (ведущие) нули и число 0 не имеет знака.
# В ответе укажите количество символов.

# %%
f = open(r"D:\informaticsclass\egeinfo\24\24_2__7bozs.txt").readline()
from re import *
mx = 0
num = r"([6-9][06-9]*|0)"
pattern = rf"{num}([-+]{num})*"
for i in finditer(pattern, f):
    mx = max(mx, len(i.group()))

print(mx)

# %% [markdown]
# Текстовый файл состоит из десятичных цифр и заглавных букв латинского алфавита. Определите в этом файле последовательность идущих подряд символов, представляющих собой запись максимального чётного 14-ричного числа. В ответе запишите количество символов (значащих цифр в записи числа) в этой последовательности.
# Примечание. Латинские буквы A, B, C и D означают цифры из алфавита 14-ричной системы счисления.

# %%
from re import *
file = open(r"D:\informaticsclass\egeinfo\24\Задание_24__7blrn.txt").readline()
mx = 0
number = "([1-9]|[A-D])([0-9]|[A-D])*[02468AC]|0|[02468AC]"

for i in finditer(number, file):
    mx = max(mx, len(i.group()))

print(mx)

# %% [markdown]
# Текстовый файл состоит из цифр 0, 6, 7, 8, 9 и знаков арифметических операций «–» и «*» (вычитание и умножение). Определите максимальное количество символов в непрерывной последовательности, которая является корректным арифметическим выражением с целыми неотрицательными числами. В этом выражении никакие два знака арифметических операций не стоят рядом, в записи чисел отсутствуют незначащие (ведущие) нули и число 0 не имеет знака.
# В ответе укажите количество символов.

# %%
file = open(r"D:\informaticsclass\egeinfo\24\demo_2025_24__7ae4q.txt").readline()
from re import *
mx = 0

number = "[1-9][0-9]*|0"
reg = f"{num}([*-]{num})+"

for i in finditer(reg, file):
    mx = max(mx, len(i.group()))
print(mx)

# %% [markdown]
# Текстовый файл состоит не более чем из 106   символов и содержит только символы, обозначающие знаки «-», «*», и цифры 0, 7, 8, 9. Определите в прилагаемом файле значение арифметического выражения у подстроки, которая содержит максимальное количество идущих подряд символов, которые образуют математически правильную последовательность, в которую входят знаки «-» или «*» и натуральные числа без незначащих нулей.
#
# В ответ запишите первые 6 цифр данного числа (знак в ответ не указывать).

# %%
from re import *
file = open(r"D:\informaticsclass\egeinfo\24\24_2__6jwgo.txt").readline()
ans = []

num = "[789][0789]*"
reg = f"{num}([-*]{num})*"

m = max([x.group() for x in finditer(reg,file)],key = len)


print(str(abs(eval(m)))[:6])

# %% [markdown]
# Текстовый файл состоит из цифр 0, 1, 2, 3, 4 и знаков арифметических операций «–» и «+» (вычитание и сложение).
# Определите максимальное количество символов в непрерывной последовательности, которая является корректным арифметическим выражением с целыми неотрицательными числами. В этом выражении никакие два знака арифметических операций не стоят рядом, в записи чисел отсутствуют незначащие (ведущие) нули и число 0 не имеет знака.
# В ответе укажите количество символов.

# %%
from re import *
file = open(r"D:\informaticsclass\egeinfo\24\24_1__7boxw.txt").readline()

number = "([1-4][0-4]*|0)"
reg = f"{number}([-+]{number})*"
mx = 0
for i in finditer(reg, file):
    mx = max(mx, len(i.group()))

print(mx)

# %% [markdown]
# Текстовый файл состоит из символов A,C,D, F   и O  .
# Определите максимальное количество идущих подряд пар символов вида
#
# согласная + гласная
# в прилагаемом файле.
# Для выполнения этого задания следует написать программу.

# %%
from re import *
file = open(r"D:\informaticsclass\egeinfo\24\Задание_24__7ajcf.txt").readline()

pair = "([CDF][AO])"
reg = f"{pair}+"
mx = 0
for i in finditer(reg, file):
    mx = max(mx, len(i.group()))
print(mx//2)

# %% [markdown]
# Текстовый файл состоит не более чем из 106   символов и содержит только цифры шестнадцатеричной системы счисления, а также знаки «+» и «*» (сложения и умножения). Определите максимальное количество символов в непрерывной последовательности, чьё значение выражения является чётным, которая является корректным арифметическим выражением с целыми неотрицательными числами, записанными в десятичной системе счисления.
#
# При этом искомая последовательность не должна являться частью другой, более длинной непрерывной последовательности, которая также является корректным арифметическим выражением.
#
# В этом выражении никакие два знака арифметических операций не стоят рядом, в записи чисел отсутствуют незначащие (ведущие) нули.

# %%
from re import *
file = open(r"D:\informaticsclass\egeinfo\24\24_1__6ba3v.txt").readline()

num = "([1-9][0-9]*|0)"
reg = f"{num}([+*]{num})+"
mx = 0

for i in finditer(reg, file):
    a = i.group()
    if eval(a) % 2 == 0:
        mx = max(mx, len(a))

print(mx)

# %% [markdown]
# Текстовый файл 24_7.txt состоит из символов, обозначающих знаки «+», «*» и десятичных цифр.
#
# Определите максимальное значение, которое является результатом вычисления непрерывной последовательности, являющейся корректным арифметическим выражением с целыми неотрицательными числами, в котором обязательно присутствует операция умножения, но операция сложения может как присутствовать, так и полностью отсутствовать.
#
# При этом искомая последовательность не должна являться частью другой, более длинной непрерывной последовательности, которая также является корректным арифметическим выражением.
#
# В этом выражении никакие два знака арифметических операций не стоят рядом. В записи чисел отсутствуют незначащие (ведущие) нули и число 0 не имеет знака.
#
# В ответе укажите значение полученного выражения.

# %%
from re import *
file = open(r"D:\informaticsclass\egeinfo\24\24_7__6ao2p.txt").readline()
mx = 0

num = "([1-9][0-9]*|0)"
reg = f"{num}([+*]{num})+"

for i in finditer(reg, file):
    if str(i.group()).count("*") >= 1:
        mx = max(mx, eval(i.group()))
print(mx)

# %% [markdown]
# № 21597 (Уровень: Сложный)
#
# Текстовый файл состоит из десятичных цифр и знаков арифметических операций «–» и «*» (вычитания и умножения).
# Определите максимальное количество символов последовательности, являющейся корректным арифметическим выражением с целыми неотрицательными 6-ричными числами, в котором порядок действий слева направо совпадает с порядком действий по правилам математики. В этом выражении никакие два знака арифметических операций не стоят рядом, в записи чисел отсутствуют незначащие (ведущие) нули.
# В ответе укажите количество символов.

# %%
from re import *

s = open(r"D:\Study\egeinfo\24\24_21597.txt").readline()

num = rf"(([1-5][0-5]*)|0)"              
pattern = rf"({num})(\*{num})*(-{num})*"
pattern = rf"(?=({pattern}))"

mx = 0  
for m in finditer(pattern, s):
    mx = max(mx, len(m.group(1)))
    print(m.group(1))

print(mx)

# %% [markdown]
# № 21421 Досрочная волна 2025 (Уровень: Базовый)
#
# Текстовый файл состоит из символов, обозначающих десятичные цифры и заглавные буквы латинского алфавита.
# Определите в прилагаемом файле максимальное количество идущих подряд символов, которые могут представлять запись чётного числа в двенадцатеричной системе счисления. В этой записи отсутствуют незначащие (ведущие) нули.
# Для выполнения этого задания следует написать программу.
# Примечание. Цифры, числовое значение которых превышает 9, обозначены латинскими буквами, начиная с буквы A.

# %%
from re import *
file = open(r"D:\Study\egeinfo\24\24_21421.txt").readline()

num = "([1-9AB][0-9AB]*[02468A])|([02468A])"
num = f"(?=({num}))"
mx = 0
for i in finditer(num, file):
    mx = max(mx, len(i.group(1)))
print(mx)
# Out:
# 19

# %% [markdown]
# № 17685 Пересдача 04.07.24 (Уровень: Гроб)
#
# Текстовый файл состоит из десятичных цифр, знаков «+» и «*» (сложения и умножения). Определите максимальное количество символов в непрерывной последовательности, являющейся корректным арифметическим выражением с целыми неотрицательными числами (без знака), значение которого равно нулю. В этом выражении никакие два знака арифметических операций не стоят рядом, порядок действий определяется по правилам математики. В записи чисел отсутствуют незначащие (ведущие) нули.
#
# В ответе укажите количество символов.

# %%
from re import * 
file = open(r"D:\Study\egeinfo\24\24_17685.txt").readline()

num = "([1-9][0-9]*)|0"
pattern = rf"({num})([+*]({num}))+"
pattern = f"(?=({pattern}))"
mx = 0

for i in finditer(pattern, file):
    i = i.group(1)
    if eval(i) == 0:
        mx = max(mx, len(i))

print(mx)
# Out:
# 169

# %% [markdown]
# № 21421 Досрочная волна 2025 (Уровень: Базовый)
#
# Текстовый файл состоит из символов, обозначающих десятичные цифры и заглавные буквы латинского алфавита.
# Определите в прилагаемом файле максимальное количество идущих подряд символов, которые могут представлять запись чётного числа в двенадцатеричной системе счисления. В этой записи отсутствуют незначащие (ведущие) нули.
# Для выполнения этого задания следует написать программу.
# Примечание. Цифры, числовое значение которых превышает 9, обозначены латинскими буквами, начиная с буквы A.

# %%
from re import *
file = open(r"D:\Study\egeinfo\24\24_21421 (1).txt").readline()

pattern = "([1-9AB][0-9AB]*[02468A])|[02468A]"
pattern = f"(?=({pattern}))"
mx = 0

for i in finditer(pattern, file):
    mx = max(mx, len(i.group(1)))

print(mx)
# Out:
# 19

# %% [markdown]
# № 18284 (Уровень: Средний)
#
# (Л. Шастин) Текстовый файл состоит не более чем из 108 символов латиницы, входящих в слово «REVOLUTION». Найдите наименьшую длину подстроки, которая включает в себя подпоследовательность символов, образующих слово «LOVE». Например, для строки REVVVLAAORRVEARRLBOLRVER ответом будет являться число 7 — это длина подстроки LBOLRVE.

# %%
from re import *
file = open(r"D:\Study\egeinfo\24\24_18284.txt").readline()

pattern = "[L][A-Z]*[O][A-Z]*[V][A-Z]*[E]"
pattern = f"(?=({pattern}))"
mn = 10 ** 7

for i in finditer(pattern, file):
    mn = min(mn, len(i.group(1)))

print(mn)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 9
#       6 mn = 10 ** 7
#       8 for i in finditer(pattern, file):
# ----> 9     mn = min(mn, len(i.group(1)))
#      11 print(mn)
#
# KeyboardInterrupt:

# %%
file = open(r"D:\Study\egeinfo\24\24_18284.txt").readline()

l = o = v = e = []
mn = 10 ** 7
for i in range(len(file)):
    s = file[i]
    if s == "L":
        l.append(i)
    if s == "O":
        o.append(i)
    if s == "V":
        v.append(i)
    if s == "E":
        e.append(i)
print(len(l), len(o), len(v), len(e))

for i in range(len(l)):
    j = 0 
    while o[j] <= l[i]:
        j += 1
    k = 0
    while v[k] <= o[j]:
        k += 1
    z = 0
    while e[z] <= v[k]:
        z += 1
    mn = min(mn, e[z] - l[i] + 1)

print(mn)
# Out:
# 1750115 1750115 1750115 1750115
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 26
#      24     z = 0
#      25     while e[z] <= v[k]:
# ---> 26         z += 1
#      27     mn = min(mn, e[z] - l[i] + 1)
#      29 print(mn)
#
# KeyboardInterrupt:

# %% [markdown]
# № 18239 (Уровень: Сложный)
#
# (Д. Бахтиев) Текстовый файл содержит цифры от 1 до 9 и знак арифметической операции «-» (вычитание). Определите максимальное количество символов в непрерывной последовательности, которая является корректным арифметическим выражением с целыми числами, чьё значение превышает -20000
# (минус двадцать тысяч). Запрещается отрывать цифры от чисел, но разрешается брать их без знака. Например, в строке -23-456-789 нельзя взять выражение -456-78, но можно взять 23-456.

# %%
from re import *
import ast
file = open(r"D:\Study\egeinfo\24\24_18239.txt").readline()

num = "[1-9]+"
pattern = f"(({num})([-]({num}))*)|(([-]({num}))([-]({num}))*)"
mx = 0

for i in finditer(pattern, file):
    i = i.group()
    if ast.literal_eval(i) > -20000:
        mx = max(mx, len(i))

print(mx)

# %%
file = open(r"D:\Study\egeinfo\24\24_18239.txt").readline()

while "--" in file:
    file = file.replace("--", " -")
file = file.split(" ")

def check(lst: str) -> int:
    start = mx = cur = 0
    lst = lst.split("-")
    for i in range(1, len(lst)):

# %% [markdown]
# (А.М. Кабанов) В текстовом файле k7a-1.txt находится цепочка из символов латинского алфавита A, B, C, D, E. Найдите длину самой длинной подцепочки, состоящей из символов A, B или C (в произвольном порядке).

# %%
file = open(r"D:\Study\egeinfo\24\24_k.txt").readline()
while "D" in file or "E" in file:
    file = file.replace("D", "*").replace("E", "*")
file = file.split("*")
print(len(max(file, key=len)))
# Out:
# 16

# %% [markdown]
# № 27069 (Уровень: Средний)
#
# (Д. Караулов) Текстовый файл состоит не более чем из 106 символов и содержит латинские буквы (прописные и строчные), точки и пробелы. Определите максимальное количество символов в непрерывной последовательности, которая является корректно записанным предложением. Считаем, что в корректно записанном предложении выполнены все следующие условия:
# – предложение начинается с заглавной буквы;
# – предложение оканчивается точкой, которая в предложении единственная и перед которой нет пробела;
# – слова в предложении состоят из произвольных комбинаций букв, возможно не имеют семантического смысла, но при этом только первая буква слова может быть заглавной;
# – слова в предложении разделены пробелами, два пробела стоять рядом в предложении не могут.
# В ответе укажите количество слов в этом предложении.

# %%
from re import *

s=open(r'D:\informaticsclass\egeinfo\24\24_27069.txt').readline()

word = r'([A-Za-z][a-z]*)'
word1 = r'([A-Z][a-z]*)'
pred = rf'{word1}( {word})+\.'

m=max((x.group() for x in finditer(pred,s)),key=len)

print(m)
# Out:
# You are a genius.

# %% [markdown]
# № 20813 Апробация 05.03.25 (Уровень: Сложный)
#
# Текстовый файл состоит из цифр 0, 7, 8, 9 и знаков арифметических операций «-» и «*» (вычитание и умножение).
# Определите максимальное количество символов в непрерывной последовательности, которая является корректным арифметическим выражением с целыми неотрицательными числами. В этом выражении никакие два знака арифметических операций не стоят рядом, в записи чисел отсутствуют незначащие (ведущие) нули и число 0 не имеет знака.
# В ответе укажите количество символов.

# %%
from re import *
file = open(r"D:\Study\egeinfo\24\24_20813.txt").readline()

num = "([789][0789]*)|0"
pattern = f"({num})([-*]({num}))+"
pattern = f"(?=({pattern}))"
mx = 0
for i in finditer(pattern, file):
    mx = max(mx, len(i.group(1)))
print(mx)

# %% [markdown]
# № 28006 (Уровень: Средний)
#
# (И. Карпачев) Текстовый файл состоит не более чем из 10^6 символов и содержит только десятичные цифры, арифметические знаки «+» и «-» и скобки «(» и «)». Определите в этом файле максимальное количество идущих подряд групп символов вида (A+B) или (A-B), где А обозначает натуральное чётное число, а B – натуральное нечётное число. В записи чисел A и B не должно быть незначащих нулей. Например, для строки (((56+-+00(0678-89)(78-9)(322+7)) ответом будет 13.

# %%
file = open(r"D:\informaticsclass\egeinfo\24\24_28006.txt").readline()
# file = "(((56+-+00(0678-89)(78-9)(322+7))"
file = file.replace("(", "I").replace(")", "J")
from re import *

num1 = "(([1-9][0-9]*[02468])|([2468]))"
num2 = "(([1-9][0-9]*[13579])|([13579]))"
pattern = f"([I]({num1}[+-]{num2})[J])*"    
pattern = f"(?=({pattern}))"
mx = 0
res = []
for i in finditer(pattern, file):
    mx = max(mx, len(i.group(1)))
print(mx)
# Out:
# 89

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from re import *
file = open(r"D:\informaticsclass\egeinfo\24\24_24895.txt").readline()

num = "([1-9]+)"
pattern = f"{num}([+*]{num})*"
pattern = f"(?=({pattern}))"

mx = 0
for i in finditer(pattern, file):
    ln = len(i.group(1))
    if len(i.group(1).replace("+", " ").replace("*", " ").split()) <= 40:
        mx = max(mx, len(i.group(1)))
print(mx)
# Out:
# 357

# %%
from re import *
file = open(r"D:\informaticsclass\egeinfo\24\24_24895.txt").readline()

num = "([1-9]+)"
pattern = f"{num}(([+*]{num}){{0,39}})"
pattern = f"(?=({pattern}))"

mx = 0
for i in finditer(pattern, file):
    ln = len(i.group(1))
    if len(i.group(1).replace("+", " ").replace("*", " ").split()) <= 40:
        mx = max(mx, len(i.group(1)))
print(mx)
# Out:
# 368

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from re import *
file = open(r"D:\informaticsclass\egeinfo\24\24_19970.txt").readline()

num = "(([1-9][0-9]*[05])|([05]))"
# конкретное количество pattern = f"{num}(([+*]{num}){{0,39}})"
pattern = f"{num}([+*]{num})+"
# используем если возможны пересечения
pattern = f"(?=({pattern}))"

mx = 0
for i in finditer(pattern, file):
    # i.group(0) не используем пересечения
    mx = max(mx, len(i.group(1)))
print(mx)
# Out:
# 91
